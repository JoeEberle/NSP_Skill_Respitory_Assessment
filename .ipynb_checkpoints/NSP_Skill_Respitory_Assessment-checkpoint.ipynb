# %% [markdown]
# ![NSP_Skill_Respitory_Assessment.png](attachment:d8c927ca-0609-4493-aed5-be55b6a22fc4.png)

# %% [markdown]
# # NSP Skill Respiratory Assessment
#
# ## National Ski Patrol (NSP) - Outdoor Emergency Care (OEC)
#
# #### Candidate Joe Eberle started on 09_20_2024 - https://github.com/JoeEberle/ - josepheberle@outlook.com
# #### Instructor : Allison Lang

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-10-24 at 21:52:41.044653

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'NSP_Skill_Respitory_Assessment'

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process NSP_Skill_Respitory_Assessment Step 0 - Initializing and starting Logging Process.

# %%
definition = '''

Here’s a clear and concise version for a respiratory assessment:

### Steps for Respiratory Assessment:

1. **Preparation**:
   - Ensure the **scene is safe** and use **standard precautions**.
   - **Introduce yourself** and obtain permission to assist.

2. **Observe Breathing**:
   - **Look and feel** for the chest to rise and fall.

3. **Assess Key Aspects**:
   - **Rate**: Count the breaths per minute.
   - **Rhythm**: Check if the breathing is regular or irregular.
   - **Depth**: Note if the breaths are shallow or deep.
   - **Effort**: Observe for any signs of labored or effortless breathing.
   - **Noise**: Listen for unusual sounds, such as wheezing, gurgling, or stridor.

''' # Add sub content for documentation 
file_name = "solution_description.md"
with open(file_name, 'w') as f:
     f.write(definition)   # Write the template to the readme.md file

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)
# Out:
# Here’s a clear and concise version for a respiratory assessment:
#
# ### Steps for Respiratory Assessment:
#
# 1. **Preparation**:
#    - Ensure the **scene is safe** and use **standard precautions**.
#    - **Introduce yourself** and obtain permission to assist.
#
# 2. **Observe Breathing**:
#    - **Look and feel** for the chest to rise and fall.
#
# 3. **Assess Key Aspects**:
#    - **Rate**: Count the breaths per minute.
#    - **Rhythm**: Check if the breathing is regular or irregular.
#    - **Depth**: Note if the breaths are shallow or deep.
#    - **Effort**: Observe for any signs of labored or effortless breathing.
#    - **Noise**: Listen for unusual sounds, such as wheezing, gurgling, or stridor.

# %%
definition = '''

### Characteristics of Normal or Good Breathing (Adults and Children):

1. **Rate**:
   - **Adults**: **12 to 20 breaths per minute**
   - **Children**:
     - **Infants (0-1 year)**: **30 to 60 breaths per minute**
     - **Toddlers (1-3 years)**: **24 to 40 breaths per minute**
     - **Preschoolers (3-6 years)**: **22 to 34 breaths per minute**
     - **School-aged children (6-12 years)**: **18 to 30 breaths per minute**
     - **Adolescents (12-18 years)**: **12 to 20 breaths per minute**

2. **Rhythm**:
   - **Regular and even**: Breathing should have a consistent pattern, with no sudden pauses or irregularities.
   - **Smooth and continuous**: Pauses between breaths should not be prolonged or erratic.

3. **Depth**:
   - **Moderate and consistent**: Each breath should involve a steady rise and fall of the chest or abdomen, depending on the age group.
   - **Age Considerations**: Infants and young children often breathe with their abdomen, which is normal.

4. **Effort**:
   - **Effortless**: Breathing should be easy, without visible strain.
   - **No use of accessory muscles**: In adults, children, and infants, there should be no exaggerated use of neck, shoulder, or abdominal muscles. Straining, nasal flaring, or grunting can indicate difficulty breathing.

5. **Noise**:
   - **Quiet and gentle**: Breathing should be silent or very faint.
   - **No abnormal sounds**: There should be no wheezing, stridor, gurgling, or other sounds that indicate a problem with airflow.
''' # Add sub content for documentation 
file_name = "solution_description.md"
with open(file_name, 'a') as f:
     f.write(definition)   # Write the template to the readme.md file

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)
# Out:
# ### Characteristics of Normal or Good Breathing (Adults and Children):
#
# 1. **Rate**:
#    - **Adults**: **12 to 20 breaths per minute**
#    - **Children**:
#      - **Infants (0-1 year)**: **30 to 60 breaths per minute**
#      - **Toddlers (1-3 years)**: **24 to 40 breaths per minute**
#      - **Preschoolers (3-6 years)**: **22 to 34 breaths per minute**
#      - **School-aged children (6-12 years)**: **18 to 30 breaths per minute**
#      - **Adolescents (12-18 years)**: **12 to 20 breaths per minute**
#
# 2. **Rhythm**:
#    - **Regular and even**: Breathing should have a consistent pattern, with no sudden pauses or irregularities.
#    - **Smooth and continuous**: Pauses between breaths should not be prolonged or erratic.
#
# 3. **Depth**:
#    - **Moderate and consistent**: Each breath should involve a steady rise and fall of the chest or abdomen, depending on the age group.
#    - **Age Considerations**: Infants and young children often breathe with their abdomen, which is normal.
#
# 4. **Effort**:
#    - **Effortless**: Breathing should be easy, without visible strain.
#    - **No use of accessory muscles**: In adults, children, and infants, there should be no exaggerated use of neck, shoulder, or abdominal muscles. Straining, nasal flaring, or grunting can indicate difficulty breathing.
#
# 5. **Noise**:
#    - **Quiet and gentle**: Breathing should be silent or very faint.
#    - **No abnormal sounds**: There should be no wheezing, stridor, gurgling, or other sounds that indicate a problem with airflow.

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-10-24 21:52:41,076 - INFO - START NSP_Skill_Respitory_Assessment =============================================
# 2024-10-24 21:52:41,076 - INFO - START NSP_Skill_Respitory_Assessment Start Time = 2024-10-24 21:52:41
# 2024-10-24 21:52:41,076 - INFO - NSP_Skill_Respitory_Assessment Step 0 - Initialize the configuration file parser
# 2024-10-24 21:52:41,077 - INFO - Process NSP_Skill_Respitory_Assessment Step 0 - Initializing and starting Logging Process.
# 2024-10-24 21:52:41,124 - INFO - PERFORMANCE NSP_Skill_Respitory_Assessment The total process duration was:0.05
# 2024-10-24 21:52:41,125 - INFO - PERFORMANCE NSP_Skill_Respitory_Assessment Stop Time = 2024-10-24 21:52:41
# 2024-10-24 21:52:41,125 - INFO - PERFORMANCE NSP_Skill_Respitory_Assessment Short process duration less than 3 Seconds:0.05
# 2024-10-24 21:52:41,125 - INFO - PERFORMANCE NSP_Skill_Respitory_Assessment Performance optimization is not reccomended
# 2024-10-24 21:52:41,125 - INFO - END NSP_Skill_Respitory_Assessment =============================================

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
